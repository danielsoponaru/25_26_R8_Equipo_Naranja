# %%
from packages.sample_ips.data_utils import procesar_network_flows

# %%
ruta_in = "Datos/Originales/Network_flows.csv"
ruta_out = "Datos/Transformados/Networkflows_100k.csv"
ruta_db = "Datos/Originales/IP2LOCATION-LITE-DB11.BIN"

# %%
df_final = procesar_network_flows(ruta_in, ruta_out, ruta_db)
# Out:
# Cargando dataset original desde: Datos/Originales/Network_flows.csv...
# Dataset cargado con exito. Filas totales: 3,577,296
# Extrayendo una muestra aleatoria de 100,000 registros...
# Conectando con la base de datos IP2Location...
# Enriqueciendo IPs de Origen...
# Enriqueciendo IPs de Destino...
# Enriquecimiento geografico completado.
# Guardando el dataset resultante en: Datos/Transformados/Networkflows_100k.csv...
# Proceso finalizado con exito. El archivo esta listo para ser enviado a la VM.

# %%
display(df_final.head())
# Out:
#                                         Flow.ID      Source.IP  Source.Port  \
# 2339780   192.168.42.58-10.200.7.6-50606-3128-6     10.200.7.6         3128
# 3456544   192.168.90.50-10.200.7.6-50075-3128-6  192.168.90.50        50075
# 2534892    192.168.60.7-10.200.7.4-51127-3128-6   192.168.60.7        51127
# 6080      10.200.7.196-68.67.178.196-33221-80-6   10.200.7.196        33221
# 601250   10.200.7.194-104.91.156.236-49141-80-6   10.200.7.194        49141
#
#          Destination.IP  Destination.Port  Protocol           Timestamp  \
# 2339780   192.168.42.58             50606         6  11/05/201709:27:41
# 3456544      10.200.7.6              3128         6  15/05/201704:41:31
# 2534892      10.200.7.4              3128         6  11/05/201709:58:31
# 6080      68.67.178.196                80         6  26/04/201711:11:37
# 601250   104.91.156.236                80         6  27/04/201709:12:00
#
#          Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  ...  \
# ...

# %%
df_final
